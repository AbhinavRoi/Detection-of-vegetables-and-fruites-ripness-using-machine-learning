# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\royab\\Downloads\\FINAL_TF2_FILES\\TF_2_Notebooks_and_Data\\vegetableAndFruitsNN'

# %%
df= pd.read_csv('spectral_color_database.csv')

# %%
df.describe().transpose()
# Out:
#           count        mean         std  min     25%     50%      75%     max
# F1        330.0   87.893939   77.660576  0.0   33.00    64.0   133.00   392.0
# F2        330.0   96.206061  108.583362  0.0   31.25    62.5   121.50   578.0
# F3        330.0  114.509091  124.688066  0.0   33.25    73.0   156.75   706.0
# F4        330.0  242.903030  307.547742  0.0   44.00   101.0   295.25  1000.0
# F5        330.0  467.703030  399.054250  0.0   85.75   326.5  1000.00  1000.0
# F6        330.0  600.393939  403.943520  0.0  179.75   686.5  1000.00  1000.0
# F7        330.0  707.066667  389.281024  0.0  414.00  1000.0  1000.00  1000.0
# F8        330.0  657.363636  376.659329  1.0  333.25   787.5  1000.00  1000.0
# NIR_1     330.0  195.878788  152.352845  0.0   86.00   152.5   293.25   748.0
# NIR_2     330.0  196.139394  153.996877  0.0   88.00   150.5   300.00   754.0
# Ripeness  330.0    1.354545    1.059790  0.0    0.00     1.0     2.00     3.0

# %%
sns.scatterplot(x='F1',y='NIR_1',data=df,)
# Out:
# <Axes: xlabel='F1', ylabel='NIR_1'>

# %%
sns.scatterplot(x='F2',y='NIR_1',data=df)
# Out:
# <Axes: xlabel='F2', ylabel='NIR_1'>

# %%
sns.scatterplot(x='F3',y='NIR_1',data=df)
# Out:
# <Axes: xlabel='F3', ylabel='NIR_1'>

# %%
sns.scatterplot(x='F4',y='NIR_1',data=df)
# Out:
# <Axes: xlabel='F4', ylabel='NIR_1'>

# %%
sns.scatterplot(x='F5',y='NIR_2',data=df)
# Out:
# <Axes: xlabel='F5', ylabel='NIR_2'>

# %%
sns.scatterplot(x='F6',y='NIR_2',data=df)
# Out:
# <Axes: xlabel='F6', ylabel='NIR_2'>

# %%
sns.scatterplot(x='F7',y='NIR_2',data=df)
# Out:
# <Axes: xlabel='F7', ylabel='NIR_2'>

# %%
sns.scatterplot(x='F8',y='NIR_2',data=df)
# Out:
# <Axes: xlabel='F8', ylabel='NIR_2'>

# %%
df= df.drop('Date',axis=1)

# %%
df
# Out:
#      F1  F2   F3   F4    F5    F6    F7   F8  NIR_1  NIR_2  Ripeness
# 0    14  14   14   45   131    65    29   63     54     66         0
# 1    18  17   18   69   191    93    39   71     62     58         0
# 2    21  19   21   76   205    98    39   71     68     54         0
# 3    97  91  122  589  1000  1000  1000  604    227    215         0
# 4    52  44   60  240   756   869   672  378    126    129         0
# ..   ..  ..  ...  ...   ...   ...   ...  ...    ...    ...       ...
# 325   1   0    1    0     0     0     4    8      4      0         3
# 326   3   3    3    2    29    34    34   27     10     10         3
# 327   4   3    4    4     1     1     0    7     16      8         3
# 328   3   3    2    2     2     2     2    8     12     10         3
# 329   2   1    1    2     3     3     2    7     10     12         3
#
# [330 rows x 11 columns]

# %%
#seperate features from labels

# %%
X= df.drop('Ripeness',axis=1).values
y= df['Ripeness'].values

# %%
#train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
# array([[ 141,  110,  143, ..., 1000,  349,  346],
#        [ 160,  127,  159, ..., 1000,  392,  392],
#        [  97,  171,  172, ...,  561,  207,  130],
#        ...,
#        [ 169,  132,  195, ..., 1000,  368,  369],
#        [ 200,  171,  251, ..., 1000,  419,  407],
#        [ 139,  155,  198, ...,  846,  291,  281]], dtype=int64)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= X_train/1000.0

# %%
X_test= X_test/1000.0

# %%
X_test
# Out:
# array([[0.109, 0.084, 0.112, 0.118, 0.712, 1.   , 1.   , 1.   , 0.273,
#         0.266],
#        [0.004, 0.003, 0.003, 0.004, 0.004, 0.004, 0.005, 0.015, 0.018,
#         0.02 ],
#        [0.176, 0.137, 0.208, 0.809, 1.   , 1.   , 1.   , 1.   , 0.36 ,
#         0.366],
#        [0.025, 0.027, 0.031, 0.05 , 0.118, 0.275, 0.417, 0.283, 0.066,
#         0.074],
#        [0.033, 0.027, 0.034, 0.086, 0.294, 0.46 , 0.549, 0.418, 0.08 ,
#         0.082],
#        [0.032, 0.037, 0.039, 0.132, 0.35 , 0.205, 0.105, 0.135, 0.088,
#         0.09 ],
#        [0.132, 0.115, 0.139, 0.135, 0.503, 1.   , 1.   , 1.   , 0.332,
#         0.324],
#        [0.044, 0.038, 0.046, 0.094, 0.305, 0.601, 0.744, 0.452, 0.118,
#         0.106],
#        [0.064, 0.051, 0.062, 0.053, 0.132, 0.728, 1.   , 1.   , 0.161,
#         0.151],
#        [0.021, 0.032, 0.032, 0.044, 0.078, 0.132, 0.286, 0.334, 0.056,
#         0.06 ],
#        [0.245, 0.212, 0.268, 0.341, 1.   , 1.   , 1.   , 1.   , 0.56 ,
# ...

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras

# %%
X_train.shape
# Out:
# (313, 10)

# %%
model = Sequential()

model.add(Dense(10,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(128,activation='relu'))
#model.add(Dense(256,activation='relu'))






model.add(Dense(4,activation= 'softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='adam')

# %%
early_stop = EarlyStopping(monitor='val_loss',mode= 'min', verbose=1, patience=25)

# %%
model.fit(x= X_train, y=y_train,epochs=600,validation_data=(X_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.3674 - val_loss: 1.3158
# Epoch 2/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2922 - val_loss: 1.2579
# Epoch 3/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2223 - val_loss: 1.1940
# Epoch 4/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1449 - val_loss: 1.0907
# Epoch 5/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0410 - val_loss: 0.9522
# Epoch 6/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9428 - val_loss: 0.8023
# Epoch 7/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7420 - val_loss: 0.6691
# Epoch 8/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6428 - val_loss: 0.5837
# Epoch 9/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6103 - val_loss: 0.5529
# Epoch 10/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5494 - val_loss: 0.5195
# Epoch 11/600
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5137 - val_loss: 0.5460
# Epoch 12/600
# ...

# %%
model_loss= pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
from tensorflow.keras.models import Sequential

# %%
probabilities = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
predictions = np.argmax(probabilities,axis=1)

# %%
predictions
# Out:
# array([1, 3, 0, 1, 3, 0, 2, 1, 2, 2, 1, 1, 0, 2, 3, 0, 2], dtype=int64)

# %%
y_test
# Out:
# array([1, 3, 0, 1, 3, 0, 2, 1, 2, 2, 1, 2, 0, 2, 3, 0, 2], dtype=int64)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y_true = np.argmax(y_test)

# %%
report= classification_report(y_test,predictions)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.80      1.00      0.89         4
#            2       1.00      0.83      0.91         6
#            3       1.00      1.00      1.00         3
#
#     accuracy                           0.94        17
#    macro avg       0.95      0.96      0.95        17
# weighted avg       0.95      0.94      0.94        17
